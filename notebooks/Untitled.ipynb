# %%
import numpy as np
import netCDF4 as nc
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
b0=nc.Dataset('/ocean/eolson/MEOPAR/NEMO-forcing/grid/bathymetry_201702.nc')
c0=nc.Dataset('/ocean/eolson/MEOPAR/NEMO-forcing/grid/coordinates_seagrid_SalishSea201702.nc')

# %%
b1=nc.Dataset('/ocean/eolson/MEOPAR/c2xuStuff/grid_Kitikmeot/ANHA12_bathymetry_sandwell_etopo1_2014_rmax_10.nc')
c1=nc.Dataset('/ocean/eolson/MEOPAR/c2xuStuff/grid_Kitikmeot/ANHA12_coordinates.nc')

# %%
b2=nc.Dataset('/ocean/eolson/MEOPAR/c2xuStuff/grid_Kitikmeot/KS60_bathymetry.nc')
c2=nc.Dataset('/ocean/eolson/MEOPAR/c2xuStuff/grid_Kitikmeot/KS60_coordinates.nc')

# %%
b0
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     Conventions: CF-1.6
#     title: Bathymetry 201702
#     institution: Dept of Earth, Ocean & Atmospheric Sciences, University of British Columbia
#     source: https://bitbucket.org/salishsea/tools/src/tip/ProcessNewRiverBathymetry.ipynb
#     references: NEMO-forcing/grid/bathymetry_201702.nc
#     history: [2017-04-12 16:27:28] Created netCDF4 zlib=True dataset.
#     comment: Bathymetry processed from Michaels New Full River Bathymetry
#     dimensions(sizes): y(898), x(398)
#     variables(dimensions): float64 nav_lon(y,x), float64 nav_lat(y,x), float64 Bathymetry(y,x)
#     groups:

# %%
c0
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF4 data model, file format HDF5):
#     history: [2017-02-14] Compressed Fraser river region
#     dimensions(sizes): x(398), y(898), time(1)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float32 time(time), float64 glamt(time,y,x), float64 glamu(time,y,x), float64 glamv(time,y,x), float64 glamf(time,y,x), float64 gphit(time,y,x), float64 gphiu(time,y,x), float64 gphiv(time,y,x), float64 gphif(time,y,x), float64 e1t(time,y,x), float64 e1u(time,y,x), float64 e1v(time,y,x), float64 e1f(time,y,x), float64 e2t(time,y,x), float64 e2u(time,y,x), float64 e2v(time,y,x), float64 e2f(time,y,x)
#     groups:

# %%
c1
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     source: extracted from orca012 grid
#     dimensions(sizes): x(1632), y(2400)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float64 glamt(y,x), float64 glamu(y,x), float64 glamv(y,x), float64 glamf(y,x), float64 gphit(y,x), float64 gphiu(y,x), float64 gphiv(y,x), float64 gphif(y,x), float64 e1t(y,x), float64 e1u(y,x), float64 e1v(y,x), float64 e1f(y,x), float64 e2t(y,x), float64 e2u(y,x), float64 e2v(y,x), float64 e2f(y,x)
#     groups:

# %%
c2
# Out:
# <class 'netCDF4._netCDF4.Dataset'>
# root group (NETCDF3_CLASSIC data model, file format NETCDF3):
#     source: extracted from ANHA12 grid
#     dimensions(sizes): x(976), y(1886)
#     variables(dimensions): float32 nav_lon(y,x), float32 nav_lat(y,x), float64 glamt(y,x), float64 glamu(y,x), float64 glamv(y,x), float64 glamf(y,x), float64 gphit(y,x), float64 gphiu(y,x), float64 gphiv(y,x), float64 gphif(y,x), float64 e1t(y,x), float64 e1u(y,x), float64 e1v(y,x), float64 e1f(y,x), float64 e2t(y,x), float64 e2u(y,x), float64 e2v(y,x), float64 e2f(y,x)
#     groups:

# %%
plt.pcolormesh(b0['Bathymetry'])
plt.colorbar()

# %%
plt.pcolormesh(b1['Bathymetry'])
plt.colorbar()

# %%
plt.pcolormesh(b2['Bathymetry'])
plt.colorbar()

# %%
for el in (b0,b1,b2):
    print(el['Bathymetry'][0,0],np.min(el['Bathymetry']),el['Bathymetry'][0,0]==0,np.max(el['Bathymetry']))
# Out:
# -- 0.0 -- 428.0
# 0.0 0.0 True 5750.0
# -0.0 -0.0 True 373.99600416112196

# %%
f3=nc.Dataset('/ocean/eolson/MEOPAR/c2xuStuff/grid_Kitikmeot/KS60_bathymetryNoNeg.nc','r')

# %%
f3.variables['Bathymetry'][:,:]=np.where(f3.variables['Bathymetry'][:,:]==0,0.0,f3.variables['Bathymetry'])

# %%
f3.close()
