# %%
import netCDF4 as nc
from matplotlib import pyplot as plt
import numpy as np
import glob

# %matplotlib inline

# %%
idir='shortTestH'

# %%
with nc.Dataset('/ocean/eolson/MEOPAR/NEMO-forcing/grid/mesh_mask201702_noLPE.nc') as mesh:
    tmask=mesh.variables['tmask'][0,:,:,:]

# %%
fU=nc.Dataset(glob.glob('/data/eolson/results/MEOPAR/SS36runs/CedarRuns/'+idir+'/SalishSea_1d_20150501_*_Malaspina_U_*.nc')[0])

# %%
fU.variables.keys()
# Out:
# dict_keys(['nav_lat', 'nav_lon', 'bounds_nav_lon', 'bounds_nav_lat', 'area', 'depthu', 'depthu_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'NO3_UT', 'ULDFNO3T'])

# %%
fU.variables['NO3_UT']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 NO3_UT(time_counter, depthu, y, x)
#     standard_name: NO3_u_dy_dz
#     long_name: Nitrate Concentration - U Transport
#     units: mmol s-1
#     online_operation: average
#     interval_operation: 40 s
#     interval_write: 1 d
#     cell_methods: time: mean (interval: 40 s)
#     cell_measures: area: area
#     _FillValue: 1e+20
#     missing_value: 1e+20
#     coordinates: time_centered nav_lat nav_lon
# unlimited dimensions: time_counter
# current shape = (2, 40, 24, 1)
# filling on

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
m0=ax[0].pcolormesh(fU.variables['NO3_UT'][0,:,:,0])
plt.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fU.variables['ULDFNO3T'][0,:,:,0])
plt.colorbar(m1,ax=ax[1])
print(np.min(fU.variables['ULDFNO3T']),np.max(fU.variables['ULDFNO3T']))
# Out:
# -88354.69 43796.926

# %%
fV=nc.Dataset(glob.glob('/data/eolson/results/MEOPAR/SS36runs/CedarRuns/'+idir+'/SalishSea_1d_20150501_*_Haro_V_*.nc')[0])

# %%
fV.variables.keys()
# Out:
# dict_keys(['nav_lat', 'nav_lon', 'bounds_nav_lon', 'bounds_nav_lat', 'area', 'depthv', 'depthv_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'NO3_VT', 'VLDFNO3T'])

# %%
fig,ax=plt.subplots(1,2,figsize=(10,5))
m0=ax[0].pcolormesh(fV.variables['NO3_VT'][0,:,0,:])
plt.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fV.variables['VLDFNO3T'][0,:,0,:])
plt.colorbar(m1,ax=ax[1])
print(np.min(fV.variables['VLDFNO3T']),np.max(fV.variables['VLDFNO3T']))
# Out:
# -54236.465 66312.28

# %%
fW=nc.Dataset(glob.glob('/data/eolson/results/MEOPAR/SS36runs/CedarRuns/'+idir+'/SalishSea_1d_20150501_*_layer6m_W_*.nc')[0])

# %%
fW.variables.keys()
# Out:
# dict_keys(['nav_lat', 'nav_lon', 'bounds_nav_lon', 'bounds_nav_lat', 'area', 'layer6m_W', 'layer6m_W_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'NO3_WT', 'VMIXNO3', 'WLDFNO3'])

# %%
fW.variables['NO3_WT']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 NO3_WT(time_counter, layer6m_W, y, x)
#     standard_name: NO3_w_dy_dx
#     long_name: Nitrate Concentration - W Transport
#     units: mmol s-1
#     online_operation: average
#     interval_operation: 40 s
#     interval_write: 1 d
#     cell_methods: time: mean (interval: 40 s)
#     cell_measures: area: area
#     _FillValue: 1e+20
#     missing_value: 1e+20
#     coordinates: time_centered nav_lat nav_lon
# unlimited dimensions: time_counter
# current shape = (2, 1, 898, 398)
# filling on

# %%
fig,ax=plt.subplots(1,3,figsize=(12,5))
m0=ax[0].pcolormesh(fW.variables['NO3_WT'][0,0,:,:])
plt.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fW.variables['VMIXNO3'][0,0,:,:],vmin=-.0005,vmax=.0005)
plt.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fW.variables['WLDFNO3'][0,0,:,:])
plt.colorbar(m2,ax=ax[2])
print(np.min(fW.variables['VMIXNO3']),np.max(fW.variables['VMIXNO3']))
# Out:
# -0.0013783523 1e+20

# %% [raw]
# fT=nc.Dataset(glob.glob('/data/eolson/results/MEOPAR/SS36runs/CedarRuns/'+idir+'/SalishSea_1d_20150501_*_ptrc_T_*.nc')[0])

# %% [raw]
# fT.variables.keys()

# %% [raw]
# fig,ax=plt.subplots(1,5,figsize=(18,5))
# #m0=ax[0].pcolormesh(fT.variables['nitrate'][0,18,:,:])
# #plt.colorbar(m0,ax=ax[0])
# m1=ax[1].pcolormesh(fT.variables['NO3_E3T'][0,18,:,:])
# plt.colorbar(m1,ax=ax[1])
# #m2=ax[2].pcolormesh(fT.variables['nitrate'][0,18,:,:]*fT.variables['e3t'][0,18,:,:]-fT.variables['NO3_E3T'][0,18,:,:])
# #plt.colorbar(m2,ax=ax[2])
# m3=ax[3].pcolormesh(fT.variables['e3t'][0,18,:,:])
# plt.colorbar(m3,ax=ax[3])
# #m4=ax[4].pcolormesh(fT.variables['ammonium'][0,2,:,:])
# #plt.colorbar(m4,ax=ax[4])

# %%
fP=nc.Dataset(glob.glob('/data/eolson/results/MEOPAR/SS36runs/CedarRuns/'+idir+'/SalishSea_1d_20150501_*_dian_T_*.nc')[0])

# %%
fP.variables.keys()
# Out:
# dict_keys(['nav_lat', 'nav_lon', 'bounds_nav_lon', 'bounds_nav_lat', 'area', 'deptht', 'deptht_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'PPDIATNO3V', 'PPPHYNO3V', 'PPMRUBNO3V', 'RIVNO3', 'BIOTRNO3', 'PHYSTRNO3', 'AFILTNO3', 'NITR', 'NO3_E3T', 'e3t'])

# %%
fig,ax=plt.subplots(1,4,figsize=(12,5))
fig.subplots_adjust(wspace=.5)
m0=ax[0].pcolormesh(fP.variables['AFILTNO3'][0,2,:,:])
plt.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fP.variables['NO3_E3T'][0,2,:,:])
plt.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fP.variables['PHYSTRNO3'][0,2,:,:])
plt.colorbar(m2,ax=ax[2])
bio=np.ma.masked_where(tmask==0,fP.variables['BIOTRNO3'][0,:,:,:])
m3=ax[3].pcolormesh(bio[2,:,:])
plt.colorbar(m3,ax=ax[3])

# %%
fig,ax=plt.subplots(1,5,figsize=(18,5))
fig.subplots_adjust(wspace=.5)
m0=ax[0].pcolormesh(fP.variables['PPDIATNO3V'][0,2,:,:])
plt.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fP.variables['PPPHYNO3V'][0,2,:,:])
plt.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fP.variables['PPMRUBNO3V'][0,2,:,:])
plt.colorbar(m2,ax=ax[2])
riv=np.ma.masked_where(tmask==0,fP.variables['RIVNO3'][0,:,:,:])
m3=ax[3].pcolormesh(riv[0,:,:])
plt.colorbar(m3,ax=ax[3])
m4=ax[4].pcolormesh(fP.variables['NITR'][0,2,:,:])
plt.colorbar(m4,ax=ax[4])
test=np.argwhere(riv[0,:,:]>0)
print(np.min(riv),np.max(riv))
ax[3].plot(test[:,1],test[:,0],'r*')
# Out:
# 0.0 248.29858

# %%
for kk in range(0,20):
    fig,ax=plt.subplots(1,1,figsize=(1,3))
    ax.plot(np.argwhere(riv[kk,:,:]>0),'r*')

# %%
np.max(bio)
# Out:
# 9.366569
