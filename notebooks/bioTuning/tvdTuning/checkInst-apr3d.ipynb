# %%
import numpy as np
import matplotlib.pyplot as plt
import netCDF4 as nc

# %matplotlib inline

# %%
f=nc.Dataset('/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/tvdTest3dapr/SalishSea_1h_20150401_20150403_dian_T_20150401-20150410.nc')
fssh=nc.Dataset('/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/tvdTest3dapr/SalishSea_1h_20150401_20150403_grid_T_20150401-20150410.nc')

# %%
f.variables.keys()
# Out:
# dict_keys(['nav_lat_grid_T', 'nav_lon_grid_T', 'bounds_nav_lon_grid_T', 'bounds_nav_lat_grid_T', 'area_grid_T', 'deptht', 'deptht_bounds', 'nav_lat_grid_W', 'nav_lon_grid_W', 'bounds_nav_lon_grid_W', 'bounds_nav_lat_grid_W', 'area_grid_W', 'depthw', 'depthw_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 'TEMPA', 'TEMPB', 'TEMPC', 'TEMPD', 'TEMPE', 'TEMPF', 'bSi', 'PHYWVEL', 'BIOWVEL', 'ZWZUPW'])

# %%
f.variables['bSi']
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# float32 bSi(time_counter, deptht, y_grid_T, x_grid_T)
#     standard_name: mole_concentration_of_organic_detritus_expressed_as_silicon_in_sea_water
#     long_name: Biogenic Silicon Concentration
#     units: mmol m-3
#     online_operation: average
#     interval_operation: 40 s
#     interval_write: 1 h
#     cell_methods: time: mean (interval: 40 s)
#     cell_measures: area: area_grid_T
#     _FillValue: 1e+20
#     missing_value: 1e+20
#     coordinates: time_centered nav_lat_grid_T nav_lon_grid_T
# unlimited dimensions: time_counter
# current shape = (72, 40, 898, 398)
# filling on

# %%
i1=217; j1=520
cols=['red','darkorange','gold','greenyellow','seagreen','turquoise','dodgerblue',
      'navy','blueviolet','fuchsia','magenta','lightpink']
len(cols)
# Out:
# 12

# %%
f.variables['bSi'][24,:,j1,i1]
# Out:
# masked_array(data=[8.05552700e-05, 8.15513340e-05, 8.19685665e-05,
#                    8.18757107e-05, 8.12692451e-05, 7.91338243e-05,
#                    1.05097046e-04, 4.92826686e-04, 1.47725194e-04,
#                    2.94751662e-04, 5.37968823e-04, 1.57021440e-03,
#                    4.39419731e-04, 1.00480078e-03, 5.20642009e-03,
#                    4.30680672e-03, 8.66714306e-03, 1.55961178e-02,
#                    1.02222683e-02, 7.69260479e-03, 8.25610245e-04,
#                    6.23779744e-02, 1.27485299e+00, 1.79377747e+00,
#                    1.42764497e+00, 9.93211985e-01, 5.96588671e-01,
#                    3.79176050e-01, 2.65121251e-01, 1.90705761e-01,
#                    1.62778839e-01, 1.63109794e-01, 1.41612262e-01,
#                    1.20875522e-01, 1.02854975e-01, 9.03575793e-02,
#                    6.69111013e-02, 3.21567655e-02, 2.10060075e-01,
#                    0.00000000e+00],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
f.variables['bSi'][60,:,j1,i1]
# Out:
# masked_array(data=[3.8454413e-09, 3.8926067e-09, 3.9272896e-09,
#                    3.9495132e-09, 3.9566057e-09, 3.8602725e-09,
#                    9.3737240e-09, 1.0068676e-08, 9.7451780e-09,
#                    2.3533058e-08, 1.0973561e-08, 1.1188248e-08,
#                    2.9714460e-09, 4.9621043e-08, 7.0528237e-08,
#                    2.7837772e-09, 1.5543012e-07, 5.8205745e-07,
#                    1.4690885e-08, 1.8382482e-06, 2.0383943e-06,
#                    1.2853451e-06, 3.9680369e-04, 2.2331133e-02,
#                    5.2872545e-01, 1.2199858e+00, 1.0587229e+00,
#                    6.9346178e-01, 4.5793188e-01, 2.9835096e-01,
#                    2.0714350e-01, 1.9376001e-01, 1.6430344e-01,
#                    1.6703589e-01, 1.1767289e-01, 9.7008862e-02,
#                    9.6456118e-02, 1.6911121e-03, 4.0320209e-01,
#                    0.0000000e+00],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
fig,ax=plt.subplots(1,5,figsize=(24,5))
jj=0
for ii in range(12,24):
    ax[0].plot(f.variables['bSi'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[jj])
    jj+=1
ax[0].set_title('12-24')
ax[0].set_ylim(40,0)

jj=0
for ii in range(24,36):
    ax[1].plot(f.variables['bSi'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[jj])
    jj+=1
ax[1].set_title('24-36')
ax[1].set_ylim(40,0)

jj=0
for ii in range(36,48):
    ax[2].plot(f.variables['bSi'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[jj])
    jj+=1
ax[2].set_title('36-48')
ax[2].set_ylim(40,0)

jj=0
for ii in range(48,60):
    ax[3].plot(f.variables['bSi'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[jj])
    jj+=1
ax[3].set_title('48-60')
ax[3].set_ylim(40,0)

jj=0
for ii in range(60,72):
    ax[4].plot(f.variables['bSi'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[jj])
    jj+=1
ax[4].set_title('60-72')
ax[4].set_ylim(40,0)
# Out:
# (40.0, 0.0)

# %% [raw]
# f2=nc.Dataset('/results/SalishSea/nowcast-green.201812/01apr15/SalishSea_1h_20150401_20150401_ptrc_T.nc')
# for ii in range(0,3):
#     plt.plot(f2.variables['biogenic_silicon'][ii,:,j1,i1],np.arange(0,40),'*')
# f2.close()

# %%
iit=24
fig,ax=plt.subplots(2,5,figsize=(22,16))
ax=ax.flatten()
tt=0
#for tt, var in enumerate(['TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 
#                          'TRALDF', 'TRBZDF', 'TRAZDF', 'bSi']):
ax[tt].set_title('TVDUPW: upwind \ncomponent of tra')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-5e-4,5e-4)
    
tt+=1
ax[tt].set_title('actual advective trend')
ax[tt].plot((0,0),(30,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TRAADV'][ii,:,j1,i1]-f.variables['TRA0'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_ylim(40,0)
ax[tt].set_xlim(-1e-5,1e-5)

tt+=1
ax[tt].set_title('ZWZUPW: zwz \n upwind component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['ZWZUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)
    
tt+=1
ax[tt].set_title('TVDAD: zwz \n antidiff component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDAD'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz \n after nonosc')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDNO'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
#non-bio w
ax[tt].set_title('PHYWVEL: phys only w')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color='dodgerblue')
#ax[tt].set_xlim(-20,20)

tt+=1
#full w BIOWVEL
ax[tt].set_title('PHYWVEL: full w \n (phys+bio)')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1]+f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
#ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('ZWZUPW: zwz diff')
var=f.variables['ZWZUPW'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDAD: zwz diff')
var=f.variables['TVDAD'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz diff')
var=f.variables['TVDNO'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
ii=24
print('w:')
print(f.variables['BIOWVEL'][ii,:,j1,i1]+f.variables['PHYWVEL'][ii,:,j1,i1])
print('C:')
print(f.variables['bSi'][ii,:,j1,i1])
# Out:
# w:
# [ -66.5973     -34.59504     -2.7165565   28.906563    60.05136
#    90.421776   114.17579    106.342415   105.85105    103.686165
#    88.46526     86.17248     74.058846    36.305183   -23.854473
#   -70.285446  -105.397675  -124.998024  -155.0094    -228.61874
#  -258.56277   -278.35208   -225.23123    -77.7863     -72.77122
#  -186.63141    -56.489185   108.21584      3.871025   -96.635605
#   -40.600544    20.52446     -6.9390144  -10.459614   -70.14894
#   -30.304188   -17.269821   -46.92218    -61.723824     0.       ]
# C:
# [8.05552700e-05 8.15513340e-05 8.19685665e-05 8.18757107e-05
#  8.12692451e-05 7.91338243e-05 1.05097046e-04 4.92826686e-04
#  1.47725194e-04 2.94751662e-04 5.37968823e-04 1.57021440e-03
#  4.39419731e-04 1.00480078e-03 5.20642009e-03 4.30680672e-03
#  8.66714306e-03 1.55961178e-02 1.02222683e-02 7.69260479e-03
#  8.25610245e-04 6.23779744e-02 1.27485299e+00 1.79377747e+00
#  1.42764497e+00 9.93211985e-01 5.96588671e-01 3.79176050e-01
#  2.65121251e-01 1.90705761e-01 1.62778839e-01 1.63109794e-01
#  1.41612262e-01 1.20875522e-01 1.02854975e-01 9.03575793e-02
#  6.69111013e-02 3.21567655e-02 2.10060075e-01 0.00000000e+00]

# %%
iit=30
fig,ax=plt.subplots(2,5,figsize=(22,16))
ax=ax.flatten()
tt=0
#for tt, var in enumerate(['TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 
#                          'TRALDF', 'TRBZDF', 'TRAZDF', 'bSi']):
ax[tt].set_title('TVDUPW: upwind \ncomponent of tra')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-5e-4,5e-4)
    
tt+=1
ax[tt].set_title('actual advective trend')
ax[tt].plot((0,0),(30,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TRAADV'][ii,:,j1,i1]-f.variables['TRA0'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_ylim(40,0)
ax[tt].set_xlim(-1e-5,1e-5)

tt+=1
ax[tt].set_title('ZWZUPW: zwz \n upwind component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['ZWZUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)
    
tt+=1
ax[tt].set_title('TVDAD: zwz \n antidiff component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDAD'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz \n after nonosc')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDNO'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
#non-bio w
ax[tt].set_title('PHYWVEL: phys only w')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color='dodgerblue')
#ax[tt].set_xlim(-20,20)

tt+=1
#full w BIOWVEL
ax[tt].set_title('PHYWVEL: full w \n (phys+bio)')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1]+f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
#ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('ZWZUPW: zwz diff')
var=f.variables['ZWZUPW'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDAD: zwz diff')
var=f.variables['TVDAD'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz diff')
var=f.variables['TVDNO'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)
# Out:
# (-20.0, 20.0)

# %%
iit=48
fig,ax=plt.subplots(2,5,figsize=(22,16))
ax=ax.flatten()
tt=0
#for tt, var in enumerate(['TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 
#                          'TRALDF', 'TRBZDF', 'TRAZDF', 'bSi']):
ax[tt].set_title('TVDUPW: upwind \ncomponent of tra')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-5e-4,5e-4)
    
tt+=1
ax[tt].set_title('actual advective trend')
ax[tt].plot((0,0),(30,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TRAADV'][ii,:,j1,i1]-f.variables['TRA0'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_ylim(40,0)
ax[tt].set_xlim(-1e-5,1e-5)

tt+=1
ax[tt].set_title('ZWZUPW: zwz \n upwind component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['ZWZUPW'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)
    
tt+=1
ax[tt].set_title('TVDAD: zwz \n antidiff component')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDAD'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz \n after nonosc')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['TVDNO'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
ax[tt].set_xlim(-20,20)

tt+=1
#non-bio w
ax[tt].set_title('PHYWVEL: phys only w')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color='dodgerblue')
#ax[tt].set_xlim(-20,20)

tt+=1
#full w BIOWVEL
ax[tt].set_title('PHYWVEL: full w \n (phys+bio)')
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(iit,iit+3):
    ax[tt].plot(f.variables['BIOWVEL'][ii,:,j1,i1]+f.variables['PHYWVEL'][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii-iit])
#ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('ZWZUPW: zwz diff')
var=f.variables['ZWZUPW'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDAD: zwz diff')
var=f.variables['TVDAD'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)

tt+=1
ax[tt].set_title('TVDNO: zwz diff')
var=f.variables['TVDNO'][iit:(iit+3),:,j1,i1]
temp=np.zeros([3,40])
temp=temp-var
temp[:,:-1]=temp[:,:-1]+var[:,1:]
ax[tt].set_ylim(40,0)
ax[tt].plot((0,0),(0,40),'k-',lw=1)
for ii in range(0,3):
    ax[tt].plot(temp[ii,:],np.arange(0,40),'*',color=cols[ii])
ax[tt].set_xlim(-20,20)
# Out:
# (-20.0, 20.0)

# %% [raw]
# f.variables['TVDNO'][:,:,j1,i1]-f.variables['TVDAD'][:,:,j1,i1]

# %% [markdown]
# ^^ **This means the nonosc code is not modifying the antidiffusive flux near the bottom**
#
# nonosc components:

# %%
f.variables.keys()
# Out:
# dict_keys(['nav_lat_grid_T', 'nav_lon_grid_T', 'bounds_nav_lon_grid_T', 'bounds_nav_lat_grid_T', 'area_grid_T', 'deptht', 'deptht_bounds', 'nav_lat_grid_W', 'nav_lon_grid_W', 'bounds_nav_lon_grid_W', 'bounds_nav_lat_grid_W', 'area_grid_W', 'depthw', 'depthw_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 'TEMPA', 'TEMPB', 'TEMPC', 'TEMPD', 'TEMPE', 'TEMPF', 'bSi', 'PHYWVEL', 'BIOWVEL', 'ZWZUPW'])

# %%
titlekey={'TEMPA':'zbetdo', 'TEMPB':'zbetup', 'TEMPC':'zup', 'TEMPD':'zdo', 'TEMPE':'zpos', 'TEMPF':'zneg'}

# %%
ii=24
fig,ax=plt.subplots(2,3,figsize=(22,18))
ax=ax.flatten()
tt=0
#for tt, var in enumerate(['TVDUPW', 'TVDAD', 'TVDNO', 'TRA0', 'TRAADV', 
#                          'TRALDF', 'TRBZDF', 'TRAZDF', 'bSi']):
for tt, var in enumerate(['TEMPA', 'TEMPB', 'TEMPC', 'TEMPD', 'TEMPE', 'TEMPF']):
    ax[tt].set_title(titlekey[var])
    ax[tt].set_ylim(40,30)
    for ii in range(0,3):
        ax[tt].plot(f.variables[var][ii,:,j1,i1],np.arange(0,40),'*',color=cols[ii])
