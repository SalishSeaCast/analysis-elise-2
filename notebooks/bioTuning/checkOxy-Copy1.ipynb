# %%
import numpy as np
import netCDF4 as nc
import matplotlib.pyplot as plt
import cmocean
import glob

# %matplotlib inline

# %%
with nc.Dataset('/data/eolson/results/MEOPAR/NEMO-forcing-new/grid/mesh_mask201702.nc') as m:
    e12t=m.variables['e1t'][0,:,:]*m.variables['e2t'][0,:,:]
    tmask=m.variables['tmask'][:,:,:,:]

# %%
#d0='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debugBefore/'
#d1='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug0/' 
db='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debugBefore/'
d0='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug0/'
d1='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug1/' 
d2='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug2b/' 
d4='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug4/' 
d4b='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug4b/' 
d5a='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug5base/' 
d5b='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug5c1/'
d5c='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/debug5c3/'

# %%
fname1='SalishSea_1h_20141106_20141107_carp_T_20141106-20141106.nc'
fname2='SalishSea_1h_20141106_20141107_ptrc_T_20141106-20141106.nc'

# %%
f0=nc.Dataset(d0+fname1)
f1=nc.Dataset(d1+fname1)#'SalishSea_1h_20141106_20141106_carp_T_20141106-20141106.nc')
f2=nc.Dataset(d2+fname1)
fpb=nc.Dataset(db+fname2)
fp0=nc.Dataset(d0+fname2)
fp1=nc.Dataset(d1+fname2)#'SalishSea_1h_20141106_20141106_ptrc_T_20141106-20141106.nc')
fp2=nc.Dataset(d1+fname2)#'SalishSea_1h_20141106_20141106_ptrc_T_20141106-20141106.nc')
fp4=nc.Dataset(d4+fname2)
fp4b=nc.Dataset(d4b+fname2)
fp5a=nc.Dataset(d5a+fname2)
fp5b=nc.Dataset(d5b+fname2)
fp5c=nc.Dataset(d5c+fname2)

# %%
np.max(np.abs(tmask*fp5c.variables['diatoms'][:,:,:,:]-tmask*fp5a.variables['diatoms'][:,:,:,:]))
# Out:
# 0.0041809604

# %%
np.max(np.abs(tmask*fp5a.variables['ciliates'][:,:,:,:]-tmask*fp5b.variables['ciliates'][:,:,:,:]))
# Out:
# 0.0

# %%
np.max(np.abs(tmask*fp4b.variables['diatoms'][:,:,:,:]-tmask*fpb.variables['diatoms'][:,:,:,:]))
# Out:
# 0.026609838

# %%
np.max(np.abs(tmask*fp4.variables['diatoms'][:,:,:,:]-tmask*fpb.variables['diatoms'][:,:,:,:]))
# Out:
# 0.026805341

# %%
np.max(np.abs(fp4.variables['ciliates'][:,:,:,:]-fpb.variables['ciliates'][:,:,:,:]))
# Out:
# 6.008777e-06

# %%
np.max(fp4.variables['ciliates'][:,:,:,:]),np.max(fpb.variables['ciliates'][:,:,:,:])
# Out:
# (0.0013616785, 0.0013616796)

# %%
np.max(fp5a.variables['ciliates'][:,:,:,:]),np.max(fp5b.variables['ciliates'][:,:,:,:])
# Out:
# (1.0735265e-08, 1.1107227e-08)

# %%
np.max(np.abs(fp4.variables['flagellates'][:,:,:,:]-fpb.variables['flagellates'][:,:,:,:]))
# Out:
# 0.11274335

# %%
np.max(np.abs(tmask*fp2.variables['diatoms'][:,:,:,:]-tmask*fpb.variables['diatoms'][:,:,:,:]))
# Out:
# 0.0

# %%
np.max(np.abs(tmask*fp2.variables['diatoms'][:,:,:,:]-tmask*fp0.variables['diatoms'][:,:,:,:]))
# Out:
# 0.0

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['diatoms'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5c.variables['diatoms'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5c.variables['diatoms'][-1,0,:,:]-fp5a.variables['diatoms'][-1,0,:,:],cmap=cmocean.cm.balance,vmin=-1.e-3,vmax=1.e-3)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['diatoms'][-1,3,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5c.variables['diatoms'][-1,3,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5c.variables['diatoms'][-1,3,:,:]-fp5a.variables['diatoms'][-1,3,:,:],cmap=cmocean.cm.balance,vmin=-1.e-3,vmax=1.e-3)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['flagellates'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5c.variables['flagellates'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5c.variables['flagellates'][-1,0,:,:]-fp5a.variables['flagellates'][-1,0,:,:],cmap=cmocean.cm.balance,vmin=-1.e-3,vmax=1.e-3)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['diatoms'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5b.variables['diatoms'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5b.variables['diatoms'][-1,0,:,:]-fp5a.variables['diatoms'][-1,0,:,:],cmap=cmocean.cm.balance,vmin=-1.e-2,vmax=1.e-2)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['flagellates'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5b.variables['flagellates'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5b.variables['flagellates'][-1,0,:,:]-fp5a.variables['flagellates'][-1,0,:,:],cmap=cmocean.cm.balance,vmin=-1.e-2,vmax=1.e-2)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp5a.variables['diatoms'][-1,3,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp5b.variables['diatoms'][-1,3,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp5b.variables['diatoms'][-1,3,:,:]-fp5a.variables['diatoms'][-1,3,:,:],cmap=cmocean.cm.balance,vmin=-1.e-4,vmax=1.e-4)
fig.colorbar(m2,ax=ax[2])

# %%
fig,ax=plt.subplots(1,3,figsize=(10,5))
fig.subplots_adjust(wspace=.4)
m0=ax[0].pcolormesh(fp4b.variables['flagellates'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(fp0.variables['flagellates'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])
m2=ax[2].pcolormesh(fp4b.variables['flagellates'][-1,0,:,:]-fp2.variables['flagellates'][-1,0,:,:],cmap=cmocean.cm.balance,vmin=-1.e-2,vmax=1.e-2)
fig.colorbar(m2,ax=ax[2])

# %%
np.unravel_index(np.argmax(fp5c.variables['diatoms'][:,:,:,:]-fp5a.variables['diatoms'][:,:,:,:]), 
                    np.shape(fp5a.variables['diatoms'][:,:,:,:]))
# Out:
# (22, 3, 818, 200)

# %%
np.unravel_index(np.argmax(fp2.variables['ciliates'][:,:,:,:]>0), 
                    np.shape(fp4.variables['diatoms'][:,:,:,:]))
# Out:
# (0, 0, 1, 131)

# %%
fig,ax=plt.subplots(1,1,figsize=(4,7))
m=ax.pcolormesh(fp2.variables['ciliates'][0,0,:,:])
fig.colorbar(m)

# %%
fig,ax=plt.subplots(1,1,figsize=(4,7))
m=ax.pcolormesh(fp5a.variables['ciliates'][0,0,:,:])
fig.colorbar(m)

# %%
f0.variables.keys()

# %%
fp0.variables.keys()

# %%
fig,ax=plt.subplots(2,4,figsize=(16,8))
fig.subplots_adjust(wspace=.5)
ax=ax.flatten()
m0=ax[0].pcolormesh(np.sum(np.mean(f0.variables['FLX_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m0,ax=ax[0])
ax[0].set_title('FLX_O2 (mmol/m2/day)')
m1=ax[1].pcolormesh(np.sum(np.mean(f0.variables['PRD_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m1,ax=ax[1])
ax[1].set_title('PRD_O2 (mmol/m2/day)')
m2=ax[2].pcolormesh(np.sum(np.mean(f0.variables['MSZ_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m2,ax=ax[2])
ax[2].set_title('MSZ_O2 (mmol/m2/day)')
m3=ax[3].pcolormesh(np.sum(np.mean(f0.variables['MRT_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m3,ax=ax[3])
ax[3].set_title('MRT_O2 (mmol/m2/day)')
m4=ax[4].pcolormesh(np.sum(np.mean(f0.variables['REM_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m4,ax=ax[4])
ax[4].set_title('REM_O2 (mmol/m2/day)')
m5=ax[5].pcolormesh(np.sum(np.mean(f0.variables['RIV_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m5,ax=ax[5])
ax[5].set_title('RIV_O2')
m6=ax[6].pcolormesh(np.sum(np.mean(f0.variables['MIZ_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m6,ax=ax[6])
ax[6].set_title('MIZ_O2')
# Out:
# Text(0.5, 1.0, 'MIZ_O2')

# %%
fig,ax=plt.subplots(2,4,figsize=(16,8))
fig.subplots_adjust(wspace=.5)
ax=ax.flatten()
m0=ax[0].pcolormesh(np.sum(np.mean(f1.variables['FLX_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m0,ax=ax[0])
ax[0].set_title('FLX_O2 (mmol/m2/day)')
m1=ax[1].pcolormesh(np.sum(np.mean(f1.variables['PRD_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m1,ax=ax[1])
ax[1].set_title('PRD_O2 (mmol/m2/day)')
m2=ax[2].pcolormesh(np.sum(np.mean(f1.variables['MSZ_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m2,ax=ax[2])
ax[2].set_title('MSZ_O2 (mmol/m2/day)')
m3=ax[3].pcolormesh(np.sum(np.mean(f1.variables['MRT_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m3,ax=ax[3])
ax[3].set_title('MRT_O2 (mmol/m2/day)')
m4=ax[4].pcolormesh(np.sum(np.mean(f1.variables['REM_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m4,ax=ax[4])
ax[4].set_title('REM_O2 (mmol/m2/day)')
m5=ax[5].pcolormesh(np.sum(np.mean(f1.variables['RIV_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m5,ax=ax[5])
ax[5].set_title('RIV_O2')
m6=ax[6].pcolormesh(np.sum(np.mean(f1.variables['MIZ_O2'][:,:,:,:]/e12t*24*3600,0),0))
fig.colorbar(m6,ax=ax[6])
ax[6].set_title('MIZ_O2')
# Out:
# Text(0.5, 1.0, 'MIZ_O2')

# %%
fig,ax=plt.subplots(1,2,figsize=(6,6))
m0=ax[0].pcolormesh(f0.variables['PRD_O2'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(f1.variables['PRD_O2'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])

# %%
fig,ax=plt.subplots(1,2,figsize=(6,6))
m0=ax[0].pcolormesh(f0.variables['FLX_O2'][-1,0,:,:])
fig.colorbar(m0,ax=ax[0])
m1=ax[1].pcolormesh(f1.variables['FLX_O2'][-1,0,:,:])
fig.colorbar(m1,ax=ax[1])

# %%
test1=nc.Dataset('/data/eolson/results/MEOPAR/NEMO-forcing-new/rivers-climatology/bio/R202101_bioConst.nc')

# %%
test2=nc.Dataset('/data/eolson/results/MEOPAR/NEMO-forcing-new/rivers-climatology/bio/R201906_bioConst.nc')

# %%
test1.variables.keys()
# Out:
# dict_keys(['no3', 'nh4', 'sil', 'dia', 'phy', 'mes', 'zoo', 'don', 'pon', 'bsi', 'tur'])

# %%
test2.variables.keys()
# Out:
# dict_keys(['no3', 'nh4', 'sil', 'dia', 'phy', 'mes', 'zoo', 'don', 'pon', 'bsi', 'tur'])

# %%
for var in test1.variables.keys():
    print(var, np.max(test1.variables[var]),np.max(test2.variables[var]))
# Out:
# no3 6.18 6.18
# nh4 4.3 4.3
# sil 59.57 59.57
# dia 0.0 0.001
# phy 0.0 0.001
# mes 0.0 0.001
# zoo 0.0 0.001
# don 0.0 0.0
# pon 0.0 0.0
# bsi 0.0 0.0
# tur 1.0 1.0

# %%
'/ocean/eolson/MEOPAR/TPARCalcs/TPAR/TPAR/paramVals.json'
# Out:
# '/ocean/eolson/MEOPAR/TPARCalcs/TPAR/TPAR/paramVals.json'
