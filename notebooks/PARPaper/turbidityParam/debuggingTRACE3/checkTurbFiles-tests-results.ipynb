# %%
import netCDF4 as nc
import matplotlib.pyplot as plt
import numpy as np
from salishsea_tools import evaltools as et
import datetime as dt
import os
import glob
import f90nml
# %matplotlib inline

# %%
with nc.Dataset('/ocean/eolson/MEOPAR/NEMO-forcing/grid/mesh_mask201702_noLPE.nc') as fm:
    print(fm.variables.keys())
    tmask=fm.variables['tmask'][0,:,:,:]
    z=fm.variables['gdept_1d'][:]
    e1e2t=fm.variables['e1t'][:,:,:]*fm.variables['e2t'][:,:,:]
# Out:
# dict_keys(['nav_lon', 'nav_lat', 'nav_lev', 'time_counter', 'tmask', 'umask', 'vmask', 'fmask', 'tmaskutil', 'umaskutil', 'vmaskutil', 'fmaskutil', 'glamt', 'glamu', 'glamv', 'glamf', 'gphit', 'gphiu', 'gphiv', 'gphif', 'e1t', 'e1u', 'e1v', 'e1f', 'e2t', 'e2u', 'e2v', 'e2f', 'ff', 'mbathy', 'misf', 'isfdraft', 'e3t_0', 'e3u_0', 'e3v_0', 'e3w_0', 'gdept_0', 'gdepu', 'gdepv', 'gdepw_0', 'gdept_1d', 'gdepw_1d', 'e3t_1d', 'e3w_1d'])

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3FixG',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3FixG
# TUR1
# TUR2
# TUR3
# TUR4
# TUR5
# TUR6
# TUR7
# TUR8
# TUR9
# TUR10

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3FixG',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,416,322],'r-')
            iax.plot(f0.variables[var][:3*24,0,416,322],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,416,322],'k-')
# Out:
# testT3FixG
# TUR1
# TUR2
# TUR3
# TUR4
# TUR5
# TUR6
# TUR7
# TUR8
# TUR9
# TUR10

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3
# TUR1
# TUR2
# TUR3
# TUR4
# TUR5
# TUR6
# TUR7
# TUR8
# TUR9
# TUR10

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3_qsrFalse',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3_qsrFalse
# TUR1
# TUR2
# TUR3
# TUR4
# TUR5
# TUR6
# TUR7
# TUR8
# TUR9
# TUR10

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3_qsrFalse2',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3_qsrFalse2
# TUR1
# TUR2
# TUR3
# TUR4
# TUR5
# TUR6
# TUR7
# TUR8
# TUR9
# TUR10

# %%
f0=nc.Dataset(glob.glob(os.path.join(rpath,'testT3_qsrFalse','SalishSea_1h_*_ptrc_T_*.nc'))[0])
f1=nc.Dataset(glob.glob(os.path.join(rpath,'testT3_qsrFalse2','SalishSea_1h_*_ptrc_T_*.nc'))[0])

# %%
f0.variables['ZWZA'][3,:10,415,345],f1.variables['ZWZA'][3,:10,415,345]
# Out:
# (masked_array(data=[    0.     ,  -746.34375, -1247.3584 , -1182.14   ,
#                         0.     ,     0.     ,     0.     ,     0.     ,
#                         0.     ,     0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[    0.     ,  -746.34375, -1247.3584 , -1182.14   ,
#                       -67.84207,     0.     ,     0.     ,     0.     ,
#                         0.     ,     0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
f0.variables['ZWZB'][3,:10,415,345],f1.variables['ZWZB'][3,:10,415,345]
# Out:
# (masked_array(data=[0.        , 0.19308074, 0.64631903, 0.36463273,
#                     0.        , 0.        , 0.        , 0.        ,
#                     0.        , 0.        ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[0.        , 0.19308083, 0.64616007, 0.48906583,
#                     0.00262153, 0.        , 0.        , 0.        ,
#                     0.        , 0.        ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
f0.variables['ZWZC'][3,:10,415,345],f1.variables['ZWZC'][3,:10,415,345]
# Out:
# (masked_array(data=[ 0.0000000e+00,  1.9308074e-01,  6.4065316e-12,
#                      3.6463273e-01, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[ 0.0000000e+00,  1.9308083e-01,  6.4065316e-12,
#                      4.8906583e-01, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
plt.pcolormesh(f0.variables['ZWZC'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
plt.pcolormesh(f1.variables['ZWZC'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
plt.pcolormesh(f0.variables['ZWZB'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
plt.pcolormesh(f1.variables['ZWZB'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
plt.pcolormesh(f0.variables['ZWZA'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
plt.pcolormesh(f1.variables['ZWZA'][:24*3,:6,415,345].T)
plt.ylim(6,0)
# Out:
# (6, 0)

# %%
f0.close()
f1.close()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-dcf10ff0f1ab> in <module>
# ----> 1 f0.close()
#       2 f1.close()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.close()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset._close()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# RuntimeError: NetCDF: Not a valid ID

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3_1bad',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3_1bad
# TUR1
# TUR2
# TUR5
# TUR6

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3_1good',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
    print(tdir)

    wd=nml['nampisriv']['wd']
    alpha_C=nml['nampisriv']['alpha_C']
    alpha_T=nml['nampisriv']['alpha_T']

    with nc.Dataset(fpath) as f0:
        vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
        rows=int(np.ceil(len(vlist)/4))
        fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
        fig.subplots_adjust(hspace=.5)
        ax=ax.flatten()
        for ii,var in zip(np.arange(0,len(vlist)),vlist):
            print(var)
            iax=ax[ii]
            varind=int(var[3:])-1
            iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
            iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
            iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
            if 'SFTURB' in f0.variables.keys():
                iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
# Out:
# testT3_1good
# TUR1
# TUR2
# TUR5
# TUR6

# %%
f0=nc.Dataset(glob.glob(os.path.join(rpath,'testT3_1good','SalishSea_1h_*_ptrc_T_*.nc'))[0])
f1=nc.Dataset(glob.glob(os.path.join(rpath,'testT3_1bad','SalishSea_1h_*_ptrc_T_*.nc'))[0])

# %%
f0.variables['ZWZA'][3,:10,415,345],f1.variables['ZWZA'][3,:10,415,345]
# Out:
# (masked_array(data=[    0.     ,  -746.34375, -1247.3584 , -1182.14   ,
#                         0.     ,     0.     ,     0.     ,     0.     ,
#                         0.     ,     0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[    0.     ,  -746.34375, -1247.3584 , -1182.14   ,
#                       -67.84207,     0.     ,     0.     ,     0.     ,
#                         0.     ,     0.     ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
f0.variables['ZWZB'][3,:10,415,345],f1.variables['ZWZB'][3,:10,415,345]
# Out:
# (masked_array(data=[0.        , 0.19308074, 0.64631903, 0.36463273,
#                     0.        , 0.        , 0.        , 0.        ,
#                     0.        , 0.        ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[0.        , 0.19308083, 0.64616007, 0.48906583,
#                     0.00262153, 0.        , 0.        , 0.        ,
#                     0.        , 0.        ],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
f0.variables['ZWZC'][3,:10,415,345],f1.variables['ZWZC'][3,:10,415,345]
# Out:
# (masked_array(data=[ 0.0000000e+00,  1.9308074e-01,  6.4065316e-12,
#                      3.6463273e-01, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32),
#  masked_array(data=[ 0.0000000e+00,  1.9308083e-01,  6.4065316e-12,
#                      4.8906583e-01, -1.4654286e+05, -0.0000000e+00,
#                     -0.0000000e+00, -0.0000000e+00, -0.0000000e+00,
#                     -0.0000000e+00],
#               mask=False,
#         fill_value=1e+20,
#              dtype=float32))

# %%
f1.variables.keys()
# Out:
# dict_keys(['nav_lat_grid_T', 'nav_lon_grid_T', 'bounds_nav_lon_grid_T', 'bounds_nav_lat_grid_T', 'area_grid_T', 'deptht', 'deptht_bounds', 'nav_lat_grid_W', 'nav_lon_grid_W', 'bounds_nav_lon_grid_W', 'bounds_nav_lat_grid_W', 'area_grid_W', 'depthw', 'depthw_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'TUR1', 'TUR2', 'TUR5', 'TUR6', 'TVDPTB1', 'ZWZA', 'ZWZB', 'ZWZC', 'SFTURB'])

# %%
plt.pcolormesh(f0.variables['TVDPTB1'][0,:,430,200:],vmin=0,vmax=5)
plt.colorbar()

# %%
f0.variables['TVDPTB1'][3,:10,415,345]
# Out:
# masked_array(data=[107.1128, 107.1128, 107.1128, 107.1128, 107.1128,
#                    107.1128, 107.1128, 107.1128, 107.1128, 107.1128],
#              mask=False,
#        fill_value=1e+20,
#             dtype=float32)

# %%
rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
dirlist=('testT3_qsrFalse',)#'testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#         'testT3_9','testT3_9a','testT3_qsrFalse')
for tdir in dirlist:
    fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
    print(tdir)
    with nc.Dataset(fpath) as f0:
        print(f0.variables.keys())
# Out:
# testT3_qsrFalse
# dict_keys(['nav_lat_grid_T', 'nav_lon_grid_T', 'bounds_nav_lon_grid_T', 'bounds_nav_lat_grid_T', 'area_grid_T', 'deptht', 'deptht_bounds', 'nav_lat_grid_W', 'nav_lon_grid_W', 'bounds_nav_lon_grid_W', 'bounds_nav_lat_grid_W', 'area_grid_W', 'depthw', 'depthw_bounds', 'time_centered', 'time_centered_bounds', 'time_counter', 'time_counter_bounds', 'TUR1', 'TUR2', 'TUR3', 'TUR4', 'TUR5', 'TUR6', 'TUR7', 'TUR8', 'TUR9', 'TUR10', 'ZWZA', 'ZWZB', 'ZWZC', 'BIOSINK1', 'ZWNBIO1', 'ZWNBIO2', 'ZWN1', 'SFTURB'])

# %% [raw]
# rpath='/data/eolson/results/MEOPAR/SS36runs/GrahamRuns/results/'
# dirlist=('testT3','testT3','testT3_2','testT3_3','testT3_4','testT3_5','testT3_6','testT3_7','testT3_8',
#          'testT3_9','testT3_9a','testT3_qsrFalse')
# for tdir in dirlist:
#     fpath=glob.glob(os.path.join(rpath,tdir,'SalishSea_1h_*_ptrc_T_*.nc'))[0]
#     nml=f90nml.read(os.path.join(rpath,tdir,'namelist_trace3_cfg'))
#
#     wd=nml['nampisriv']['wd']
#     alpha_C=nml['nampisriv']['alpha_C']
#     alpha_T=nml['nampisriv']['alpha_T']
#
#     with nc.Dataset(fpath) as f0:
#         vlist=[el for el in f0.variables.keys() if el.startswith('TUR')]
#         rows=int(np.ceil(len(vlist)/4))
#         fig,ax=plt.subplots(rows,4,figsize=(16,4*rows))
#         fig.subplots_adjust(hspace=.5)
#         ax=ax.flatten()
#         for ii,var in zip(np.arange(0,len(vlist)),vlist):
#             iax=ax[ii]
#             varind=int(var[3:])-1
#             iax.set_title('{}: {}\n aT={}, wd={}, aC={}'.format(tdir,var,alpha_T[varind],wd[varind],alpha_C[varind]))
#             iax.plot(f0.variables[var][:3*24,3,415,345],'r-')
#             iax.plot(f0.variables[var][:3*24,0,415,345],'b-')
#             if 'SFTURB' in f0.variables.keys():
#                 iax.plot(f0.variables['SFTURB'][:3*24,415,345],'k-')
